# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Your API Key
api_key = weather_api_key

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | colonia
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | la sarre
# Processing Record 5 of Set 1 | whitehorse
# Processing Record 6 of Set 1 | shizuoka
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | alaghsas
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | bilibino
# Processing Record 14 of Set 1 | marsabit
# Processing Record 15 of Set 1 | haiku-pauwela
# Processing Record 16 of Set 1 | kidatu
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | chernyshevskiy
# Processing Record 20 of Set 1 | mazara del vallo
# Processing Record 21 of Set 1 | lagunas
# Processing Record 22 of Set 1 | middlesboro
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | mossel bay
# Processing Record 26 of Set 1 | altai
# Processing Record 27 of Set 1 | iskateley
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | turinsk
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | ust-nera
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | lautoka
# Processing Record 35 of Set 1 | west island
# Processing Record 36 of Set 1 | irymple
# Processing Record 37 of Set 1 | wailua homesteads
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | saipan
# Processing Record 40 of Set 1 | port lavaca
# Processing Record 41 of Set 1 | fale old settlement
# Processing Record 42 of Set 1 | puerto el triunfo
# Processing Record 43 of Set 1 | oranjemund
# Processing Record 44 of Set 1 | margaret river
# Processing Record 45 of Set 1 | port lincoln
# Processing Record 46 of Set 1 | patnanungan
# Processing Record 47 of Set 1 | malanje
# Processing Record 48 of Set 1 | sinabang
# Processing Record 49 of Set 1 | hammerfest
# Processing Record 50 of Set 1 | forbes
# Processing Record 0 of Set 2 | yagry
# City not found. Skipping...
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | afaahiti
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | zouerate
# Processing Record 6 of Set 2 | olonkinbyen
# Processing Record 7 of Set 2 | anadyr
# Processing Record 8 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 2 | lambarene
# Processing Record 10 of Set 2 | nova vicosa
# Processing Record 11 of Set 2 | yichang
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | stanley
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | quellon
# Processing Record 16 of Set 2 | alice springs
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | gadzhiyevo
# Processing Record 19 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | tateyama
# Processing Record 22 of Set 2 | prince rupert
# Processing Record 23 of Set 2 | miramichi
# Processing Record 24 of Set 2 | sorsk
# Processing Record 25 of Set 2 | aitape
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | sokol'skoye
# Processing Record 28 of Set 2 | atafu village
# Processing Record 29 of Set 2 | port mathurin
# Processing Record 30 of Set 2 | momignies
# Processing Record 31 of Set 2 | yarmouth
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | kingston
# Processing Record 34 of Set 2 | dudinka
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | usinsk
# Processing Record 39 of Set 2 | invercargill
# Processing Record 40 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 41 of Set 2 | tralee
# Processing Record 42 of Set 2 | tambura
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | chonchi
# Processing Record 45 of Set 2 | high river
# Processing Record 46 of Set 2 | kirakira
# Processing Record 47 of Set 2 | nogliki
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | naze
# Processing Record 0 of Set 3 | port elizabeth
# Processing Record 1 of Set 3 | sylva
# Processing Record 2 of Set 3 | reuleuet
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | necochea
# Processing Record 5 of Set 3 | ulsteinvik
# Processing Record 6 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 7 of Set 3 | puerto natales
# Processing Record 8 of Set 3 | dongyang
# Processing Record 9 of Set 3 | sikonge
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | zavodskoy
# Processing Record 14 of Set 3 | papao
# Processing Record 15 of Set 3 | masterton
# Processing Record 16 of Set 3 | tafuna
# Processing Record 17 of Set 3 | maiwut
# City not found. Skipping...
# Processing Record 18 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 19 of Set 3 | lodja
# Processing Record 20 of Set 3 | san clemente del tuyu
# Processing Record 21 of Set 3 | cobija
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | merizo village
# Processing Record 24 of Set 3 | polyarnyy
# Processing Record 25 of Set 3 | santa marinella
# Processing Record 26 of Set 3 | lihue
# Processing Record 27 of Set 3 | herbstein
# Processing Record 28 of Set 3 | tihuatlan
# Processing Record 29 of Set 3 | broken hill
# Processing Record 30 of Set 3 | arfoud
# Processing Record 31 of Set 3 | kourou
# Processing Record 32 of Set 3 | ovalle
# Processing Record 33 of Set 3 | lubao
# Processing Record 34 of Set 3 | huazhou
# Processing Record 35 of Set 3 | sao tome
# Processing Record 36 of Set 3 | nuuk
# Processing Record 37 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | nikolayevsk-on-amure
# Processing Record 40 of Set 3 | minas de marcona
# Processing Record 41 of Set 3 | badger
# Processing Record 42 of Set 3 | labuan
# Processing Record 43 of Set 3 | center
# Processing Record 44 of Set 3 | bunia
# Processing Record 45 of Set 3 | delijan
# Processing Record 46 of Set 3 | hawaiian paradise park
# Processing Record 47 of Set 3 | papatowai
# Processing Record 48 of Set 3 | blackwater
# Processing Record 49 of Set 3 | lloydminster
# Processing Record 0 of Set 4 | kill devil hills
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | pokachi
# Processing Record 3 of Set 4 | dunedin
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | malango
# Processing Record 6 of Set 4 | chizhou
# Processing Record 7 of Set 4 | constantia
# Processing Record 8 of Set 4 | yaren
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | sasso marconi
# Processing Record 11 of Set 4 | calenzano
# Processing Record 12 of Set 4 | newnham
# Processing Record 13 of Set 4 | monrovia
# Processing Record 14 of Set 4 | chalus
# Processing Record 15 of Set 4 | pierre
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | st. john's
# Processing Record 18 of Set 4 | xilin hot
# Processing Record 19 of Set 4 | remire-montjoly
# Processing Record 20 of Set 4 | aoulef
# Processing Record 21 of Set 4 | happy valley-goose bay
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | am timan
# Processing Record 24 of Set 4 | tazovsky
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | jamestown
# Processing Record 27 of Set 4 | kununurra
# Processing Record 28 of Set 4 | turan
# Processing Record 29 of Set 4 | shimoda
# Processing Record 30 of Set 4 | san antonio de pale
# Processing Record 31 of Set 4 | new plymouth
# Processing Record 32 of Set 4 | klyuchi
# Processing Record 33 of Set 4 | port isabel
# Processing Record 34 of Set 4 | basoko
# Processing Record 35 of Set 4 | udachny
# Processing Record 36 of Set 4 | oum hadjer
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | kavieng
# Processing Record 39 of Set 4 | acarau
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | baskale
# Processing Record 42 of Set 4 | vorkuta
# Processing Record 43 of Set 4 | kayangel
# Processing Record 44 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 4 | inarajan village
# Processing Record 46 of Set 4 | isafjordur
# Processing Record 47 of Set 4 | keflavik
# Processing Record 48 of Set 4 | juneau
# Processing Record 49 of Set 4 | labrador city
# Processing Record 0 of Set 5 | lompoc
# Processing Record 1 of Set 5 | sarmiento
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | mount pearl
# Processing Record 4 of Set 5 | praia da vitoria
# Processing Record 5 of Set 5 | sumbawa besar
# Processing Record 6 of Set 5 | susuman
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | port macquarie
# Processing Record 9 of Set 5 | yanam
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | barakani
# Processing Record 12 of Set 5 | polonnaruwa
# Processing Record 13 of Set 5 | santa marta
# Processing Record 14 of Set 5 | kidal
# Processing Record 15 of Set 5 | newman
# Processing Record 16 of Set 5 | guarapari
# Processing Record 17 of Set 5 | savave village
# City not found. Skipping...
# Processing Record 18 of Set 5 | kharkhorin
# Processing Record 19 of Set 5 | benghazi
# Processing Record 20 of Set 5 | freetown
# Processing Record 21 of Set 5 | port saint john's
# Processing Record 22 of Set 5 | college
# Processing Record 23 of Set 5 | kuta
# Processing Record 24 of Set 5 | mili
# Processing Record 25 of Set 5 | oliena
# Processing Record 26 of Set 5 | dundaga
# Processing Record 27 of Set 5 | posto fiscal rolim de moura
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | ibimirim
# Processing Record 30 of Set 5 | vera cruz
# Processing Record 31 of Set 5 | callao
# Processing Record 32 of Set 5 | kerikeri
# Processing Record 33 of Set 5 | mareeba
# Processing Record 34 of Set 5 | el porvenir
# Processing Record 35 of Set 5 | muscat
# Processing Record 36 of Set 5 | utrik
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | san luis de la loma
# Processing Record 39 of Set 5 | celestun
# Processing Record 40 of Set 5 | takoradi
# Processing Record 41 of Set 5 | wakkanai
# Processing Record 42 of Set 5 | lake havasu city
# Processing Record 43 of Set 5 | saalfeld
# Processing Record 44 of Set 5 | cole harbour
# Processing Record 45 of Set 5 | uturoa
# Processing Record 46 of Set 5 | katsuura
# Processing Record 47 of Set 5 | bel ombre
# Processing Record 48 of Set 5 | xiaoweizhai
# Processing Record 49 of Set 5 | tommot
# Processing Record 0 of Set 6 | sitka
# Processing Record 1 of Set 6 | wynyard
# Processing Record 2 of Set 6 | acoyapa
# Processing Record 3 of Set 6 | shingu
# Processing Record 4 of Set 6 | uthal
# Processing Record 5 of Set 6 | sandnessjoen
# Processing Record 6 of Set 6 | hilo
# Processing Record 7 of Set 6 | howard springs
# Processing Record 8 of Set 6 | robbah
# Processing Record 9 of Set 6 | palmer
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | santa luzia
# Processing Record 12 of Set 6 | chinsali
# Processing Record 13 of Set 6 | dubbo
# Processing Record 14 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 15 of Set 6 | wenchang
# Processing Record 16 of Set 6 | katsuren-haebaru
# Processing Record 17 of Set 6 | carolina beach
# Processing Record 18 of Set 6 | severo-yeniseyskiy
# Processing Record 19 of Set 6 | reggane
# Processing Record 20 of Set 6 | mukah
# City not found. Skipping...
# Processing Record 21 of Set 6 | sodankyla
# Processing Record 22 of Set 6 | chipiona
# Processing Record 23 of Set 6 | gazli
# Processing Record 24 of Set 6 | kanchipuram
# Processing Record 25 of Set 6 | glace bay
# Processing Record 26 of Set 6 | puerto aysen
# Processing Record 27 of Set 6 | port douglas
# Processing Record 28 of Set 6 | fort bragg
# Processing Record 29 of Set 6 | brisas de zicatela
# Processing Record 30 of Set 6 | chibougamau
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | kiunga
# Processing Record 33 of Set 6 | enewetak
# Processing Record 34 of Set 6 | vorgashor
# Processing Record 35 of Set 6 | la ronge
# Processing Record 36 of Set 6 | kruisfontein
# Processing Record 37 of Set 6 | yuzhno-kurilsk
# Processing Record 38 of Set 6 | tsiombe
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | matui
# Processing Record 41 of Set 6 | wamba
# Processing Record 42 of Set 6 | campbell river
# Processing Record 43 of Set 6 | la'ie
# Processing Record 44 of Set 6 | smithers
# Processing Record 45 of Set 6 | agboville
# Processing Record 46 of Set 6 | malakal
# Processing Record 47 of Set 6 | carloforte
# Processing Record 48 of Set 6 | cacoal
# Processing Record 49 of Set 6 | tranqueras
# Processing Record 0 of Set 7 | wad medani
# Processing Record 1 of Set 7 | langsa
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | tomatlan
# Processing Record 4 of Set 7 | zhanaozen
# Processing Record 5 of Set 7 | linhares
# Processing Record 6 of Set 7 | wathlingen
# Processing Record 7 of Set 7 | pijijiapan
# Processing Record 8 of Set 7 | khovd
# Processing Record 9 of Set 7 | kitimat
# Processing Record 10 of Set 7 | sao jose da coroa grande
# Processing Record 11 of Set 7 | iquitos
# Processing Record 12 of Set 7 | puerto la cruz
# Processing Record 13 of Set 7 | crane
# Processing Record 14 of Set 7 | okhotsk
# Processing Record 15 of Set 7 | sao gabriel da cachoeira
# Processing Record 16 of Set 7 | new norfolk
# Processing Record 17 of Set 7 | boende
# Processing Record 18 of Set 7 | adrar
# Processing Record 19 of Set 7 | cockburn town
# Processing Record 20 of Set 7 | yreka
# Processing Record 21 of Set 7 | ta`u
# Processing Record 22 of Set 7 | nokha
# Processing Record 23 of Set 7 | labasa
# Processing Record 24 of Set 7 | suoyarvi
# Processing Record 25 of Set 7 | north bend
# Processing Record 26 of Set 7 | muisne
# Processing Record 27 of Set 7 | cabedelo
# Processing Record 28 of Set 7 | pahrump
# Processing Record 29 of Set 7 | guanare
# Processing Record 30 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 31 of Set 7 | malvan
# Processing Record 32 of Set 7 | mugumu
# Processing Record 33 of Set 7 | kapa'a
# Processing Record 34 of Set 7 | biloela
# Processing Record 35 of Set 7 | muynoq
# Processing Record 36 of Set 7 | bedford
# Processing Record 37 of Set 7 | inekar
# City not found. Skipping...
# Processing Record 38 of Set 7 | fairwood
# Processing Record 39 of Set 7 | martuk
# Processing Record 40 of Set 7 | holualoa
# Processing Record 41 of Set 7 | dalnegorsk
# Processing Record 42 of Set 7 | soe
# Processing Record 43 of Set 7 | touros
# Processing Record 44 of Set 7 | egilsstadir
# Processing Record 45 of Set 7 | lages
# Processing Record 46 of Set 7 | sorong
# Processing Record 47 of Set 7 | catarama
# Processing Record 48 of Set 7 | xining
# Processing Record 49 of Set 7 | tshabong
# Processing Record 0 of Set 8 | dosso
# Processing Record 1 of Set 8 | bikenibeu village
# Processing Record 2 of Set 8 | roldan
# Processing Record 3 of Set 8 | zhosaly
# Processing Record 4 of Set 8 | serhiyivka
# Processing Record 5 of Set 8 | beira
# Processing Record 6 of Set 8 | sinop
# Processing Record 7 of Set 8 | taupo
# Processing Record 8 of Set 8 | midvagur
# Processing Record 9 of Set 8 | bamboo flat
# Processing Record 10 of Set 8 | swakopmund
# Processing Record 11 of Set 8 | galliano
# Processing Record 12 of Set 8 | al ghayzah
# Processing Record 13 of Set 8 | novodvinsk
# Processing Record 14 of Set 8 | grandview
# Processing Record 15 of Set 8 | joshimath
# Processing Record 16 of Set 8 | envira
# Processing Record 17 of Set 8 | tutong
# Processing Record 18 of Set 8 | sile
# Processing Record 19 of Set 8 | nar'yan-mar
# Processing Record 20 of Set 8 | baluntaicun
# City not found. Skipping...
# Processing Record 21 of Set 8 | 'alaqahdari dishu
# Processing Record 22 of Set 8 | richards bay
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | petukhovo
# Processing Record 25 of Set 8 | losal
# Processing Record 26 of Set 8 | aasiaat
# Processing Record 27 of Set 8 | suva
# Processing Record 28 of Set 8 | portland
# Processing Record 29 of Set 8 | port alfred
# Processing Record 30 of Set 8 | khandyga
# Processing Record 31 of Set 8 | kisangani
# Processing Record 32 of Set 8 | kodiak
# Processing Record 33 of Set 8 | bredy
# Processing Record 34 of Set 8 | aykhal
# Processing Record 35 of Set 8 | tucupita
# Processing Record 36 of Set 8 | fort-shevchenko
# Processing Record 37 of Set 8 | fuyuan
# Processing Record 38 of Set 8 | bayou cane
# Processing Record 39 of Set 8 | pemba
# Processing Record 40 of Set 8 | general mosconi
# Processing Record 41 of Set 8 | kulhudhuffushi
# Processing Record 42 of Set 8 | lubang
# Processing Record 43 of Set 8 | horqueta
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | fuglafjordur
# Processing Record 46 of Set 8 | colares
# Processing Record 47 of Set 8 | kapuskasing
# Processing Record 48 of Set 8 | torres
# Processing Record 49 of Set 8 | hatillo
# Processing Record 0 of Set 9 | turpan
# Processing Record 1 of Set 9 | ghat
# Processing Record 2 of Set 9 | santa elena de uairen
# Processing Record 3 of Set 9 | porto novo
# Processing Record 4 of Set 9 | nova friburgo
# Processing Record 5 of Set 9 | queenstown
# Processing Record 6 of Set 9 | argostolion
# Processing Record 7 of Set 9 | balcarce
# Processing Record 8 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 9 of Set 9 | rongelap
# Processing Record 10 of Set 9 | thinadhoo
# Processing Record 11 of Set 9 | ola
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | maubara
# City not found. Skipping...
# Processing Record 14 of Set 9 | hithadhoo
# Processing Record 15 of Set 9 | merritt island
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | ust-tsilma
# Processing Record 18 of Set 9 | mpanda
# Processing Record 19 of Set 9 | namtsy
# Processing Record 20 of Set 9 | preobrazheniye
# Processing Record 21 of Set 9 | yonkers
# Processing Record 22 of Set 9 | tachilek
# City not found. Skipping...
# Processing Record 23 of Set 9 | lisala
# Processing Record 24 of Set 9 | lionel town
# Processing Record 25 of Set 9 | axim
# Processing Record 26 of Set 9 | mejit
# Processing Record 27 of Set 9 | al mijlad
# Processing Record 28 of Set 9 | kralendijk
# Processing Record 29 of Set 9 | xichang
# Processing Record 30 of Set 9 | belmonte
# Processing Record 31 of Set 9 | gorontalo
# Processing Record 32 of Set 9 | eyl
# Processing Record 33 of Set 9 | kismayo
# Processing Record 34 of Set 9 | arucas
# Processing Record 35 of Set 9 | tolanaro
# Processing Record 36 of Set 9 | shangrao
# Processing Record 37 of Set 9 | san rafael
# Processing Record 38 of Set 9 | falkenberg
# Processing Record 39 of Set 9 | monkey bay
# Processing Record 40 of Set 9 | alvorada
# Processing Record 41 of Set 9 | airuk
# Processing Record 42 of Set 9 | stephenville
# Processing Record 43 of Set 9 | hami
# Processing Record 44 of Set 9 | fort mcmurray
# Processing Record 45 of Set 9 | nueva gerona
# Processing Record 46 of Set 9 | buka
# Processing Record 47 of Set 9 | tanki leendert
# City not found. Skipping...
# Processing Record 48 of Set 9 | flying fish cove
# Processing Record 49 of Set 9 | nhlangano
# Processing Record 0 of Set 10 | soure
# Processing Record 1 of Set 10 | rio grande
# Processing Record 2 of Set 10 | lusambo
# Processing Record 3 of Set 10 | abay
# Processing Record 4 of Set 10 | biankouma
# Processing Record 5 of Set 10 | souillac
# Processing Record 6 of Set 10 | kertih
# Processing Record 7 of Set 10 | quibdo
# Processing Record 8 of Set 10 | argo
# Processing Record 9 of Set 10 | kissidougou
# Processing Record 10 of Set 10 | moussoro
# Processing Record 11 of Set 10 | naryn
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | kone
# Processing Record 14 of Set 10 | trabzon
# Processing Record 15 of Set 10 | ukiah
# Processing Record 16 of Set 10 | moapa valley
# Processing Record 17 of Set 10 | rio pardo de minas
# Processing Record 18 of Set 10 | rabo de peixe
# Processing Record 19 of Set 10 | itaituba
# Processing Record 20 of Set 10 | mitu
# Processing Record 21 of Set 10 | bafoulabe
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | weno
# Processing Record 24 of Set 10 | alappuzha
# Processing Record 25 of Set 10 | la passe
# Processing Record 26 of Set 10 | antsiranana
# Processing Record 27 of Set 10 | olinda
# Processing Record 28 of Set 10 | harper
# Processing Record 29 of Set 10 | isangel
# Processing Record 30 of Set 10 | melilla
# Processing Record 31 of Set 10 | urengoy
# Processing Record 32 of Set 10 | lesnoy
# Processing Record 33 of Set 10 | ad dilam
# Processing Record 34 of Set 10 | vanimo
# Processing Record 35 of Set 10 | znamenskoye
# Processing Record 36 of Set 10 | gornozavodsk
# Processing Record 37 of Set 10 | yatou
# Processing Record 38 of Set 10 | bolong
# Processing Record 39 of Set 10 | san andres
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | figuig (centre)
# Processing Record 42 of Set 10 | kuressaare
# Processing Record 43 of Set 10 | guelmim
# Processing Record 44 of Set 10 | al wajh
# Processing Record 45 of Set 10 | margate
# Processing Record 46 of Set 10 | puerto quijarro
# Processing Record 47 of Set 10 | lesogorsk
# Processing Record 48 of Set 10 | cambria
# Processing Record 49 of Set 10 | vilyuchinsk
# Processing Record 0 of Set 11 | peace river
# Processing Record 1 of Set 11 | fortaleza
# Processing Record 2 of Set 11 | arkalyk
# Processing Record 3 of Set 11 | urzhar
# Processing Record 4 of Set 11 | catalhoyuk
# Processing Record 5 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 11 | tynda
# Processing Record 7 of Set 11 | nadym
# Processing Record 8 of Set 11 | kuqa
# Processing Record 9 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 10 of Set 11 | n'zeto
# Processing Record 11 of Set 11 | palikir - national government center
# Processing Record 12 of Set 11 | rio gallegos
# Processing Record 13 of Set 11 | gaspe
# Processing Record 14 of Set 11 | mashhad
# Processing Record 15 of Set 11 | grand falls-windsor
# Processing Record 16 of Set 11 | warwick
# Processing Record 17 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 11 | namie
# Processing Record 19 of Set 11 | guerrero negro
# Processing Record 20 of Set 11 | sonari
# Processing Record 21 of Set 11 | primero de mayo
# Processing Record 22 of Set 11 | bazarak
# Processing Record 23 of Set 11 | orcopampa
# Processing Record 24 of Set 11 | samarra'
# City not found. Skipping...
# Processing Record 25 of Set 11 | san ignacio de velasco
# Processing Record 26 of Set 11 | hwange
# Processing Record 27 of Set 11 | coahuayana de hidalgo
# Processing Record 28 of Set 11 | mukalla
# Processing Record 29 of Set 11 | guanica
# Processing Record 30 of Set 11 | nicoya
# Processing Record 31 of Set 11 | pimentel
# Processing Record 32 of Set 11 | kaliganj
# Processing Record 33 of Set 11 | krishnarajpet
# Processing Record 34 of Set 11 | watseka
# Processing Record 35 of Set 11 | luena
# Processing Record 36 of Set 11 | tulun
# Processing Record 37 of Set 11 | yeniseysk
# Processing Record 38 of Set 11 | ulanhot
# Processing Record 39 of Set 11 | noosa heads
# Processing Record 40 of Set 11 | fatehgarh
# Processing Record 41 of Set 11 | nizhnyaya tavda
# Processing Record 42 of Set 11 | khash
# Processing Record 43 of Set 11 | vila franca do campo
# Processing Record 44 of Set 11 | nurota
# Processing Record 45 of Set 11 | walvis bay
# Processing Record 46 of Set 11 | kutum
# Processing Record 47 of Set 11 | pangkalpinang
# Processing Record 48 of Set 11 | kisanga
# Processing Record 49 of Set 11 | gonabad
# Processing Record 0 of Set 12 | kendari
# Processing Record 1 of Set 12 | alofi
# Processing Record 2 of Set 12 | quthing
# Processing Record 3 of Set 12 | nova sintra
# Processing Record 4 of Set 12 | ulysses
# Processing Record 5 of Set 12 | viedma
# Processing Record 6 of Set 12 | chul'man
# Processing Record 7 of Set 12 | takamaka
# City not found. Skipping...
# Processing Record 8 of Set 12 | copala
# Processing Record 9 of Set 12 | kristiansund
# Processing Record 10 of Set 12 | tromso
# Processing Record 11 of Set 12 | ayorou
# Processing Record 12 of Set 12 | balaka
# Processing Record 13 of Set 12 | okha
# Processing Record 14 of Set 12 | boguchany
# Processing Record 15 of Set 12 | strathalbyn
# Processing Record 16 of Set 12 | vadso
# Processing Record 17 of Set 12 | sanctuary point
# Processing Record 18 of Set 12 | kasongo-lunda
# Processing Record 19 of Set 12 | pergamino
# Processing Record 20 of Set 12 | tongshan
# Processing Record 21 of Set 12 | hakha
# Processing Record 22 of Set 12 | acapulco de juarez
# Processing Record 23 of Set 12 | skowhegan
# Processing Record 24 of Set 12 | ilabaya
# Processing Record 25 of Set 12 | maintirano
# Processing Record 26 of Set 12 | bambari
# Processing Record 27 of Set 12 | arteche
# Processing Record 28 of Set 12 | saint-pierre
# Processing Record 29 of Set 12 | ubari
# Processing Record 30 of Set 12 | kyelang
# Processing Record 31 of Set 12 | sofifi
# City not found. Skipping...
# Processing Record 32 of Set 12 | gemena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            colonia  50.9333    6.9500     22.36        67         100
# 1           westport  41.1415  -73.3579     31.72        47           0
# 2  port-aux-francais -49.3500   70.2167      6.25        82          81
# 3           la sarre  48.8002  -79.1996     26.15        35          24
# 4         whitehorse  60.7161 -135.0538     12.43       100         100
#
#    Wind Speed Country        Date
# 0        5.66      DE  1690135484
# 1        3.58      US  1690135289
# 2       17.69      TF  1690135485
# 3        3.09      CA  1690135485
# 4        1.03      CA  1690135485

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  colonia  50.9333    6.9500     22.36        67         100
# 1                 westport  41.1415  -73.3579     31.72        47           0
# 2        port-aux-francais -49.3500   70.2167      6.25        82          81
# 3                 la sarre  48.8002  -79.1996     26.15        35          24
# 4               whitehorse  60.7161 -135.0538     12.43       100         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      DE  1690135484
# 1              3.58      US  1690135289
# 2             17.69      TF  1690135485
# 3              3.09      CA  1690135485
# 4              1.03      CA  1690135485

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    #Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    # Get the limits of the current plot and use them to calculate relative position
    xlim = plt.gca().get_xlim()
    ylim = plt.gca().get_ylim()
    x_text = xlim[0] + (xlim[1] - xlim[0])*0.5 # 50% from the left
    y_text = ylim[0] + (ylim[1] - ylim[0])*0.05 # 5% from the bottom
    plt.annotate(line_eq,(x_text, y_text),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           colonia  50.9333    6.9500     22.36        67         100
# 1          westport  41.1415  -73.3579     31.72        47           0
# 3          la sarre  48.8002  -79.1996     26.15        35          24
# 4        whitehorse  60.7161 -135.0538     12.43       100         100
# 5          shizuoka  34.9769  138.3831     23.19        85          27
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      DE  1690135484
# 1              3.58      US  1690135289
# 3              3.09      CA  1690135485
# 4              1.03      CA  1690135485
# 5              1.22      JP  1690135200

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3500   70.2167      6.25        82          81
# 7            blackmans bay -43.0167  147.3167      9.18        78          92
# 8                adamstown -25.0660 -130.1015     20.50        71           9
# 10                cidreira -30.1811  -50.2056     24.05        66          71
# 11              bredasdorp -34.5322   20.0403      8.66        87          50
#
#          Wind Speed Country        Date
# City_ID
# 2             17.69      TF  1690135485
# 7              1.89      AU  1690135485
# 8              8.54      PN  1690135486
# 10             1.93      BR  1690135486
# 11             3.02      ZA  1690135486

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
title = "Max Temp"
text_coordinates = (0, -20)
plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.38696232831431665

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
title = "Max Temp"
text_coordinates = (-50, 90)
plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.682842098641331

# %% [markdown]
# There is quite moderate relationship even moderate to storng in Southern Hemisphere, so that whilst Latitude decreasass, temperature levels tend to increase as well, however much weaker trend is modelled in the Northern Hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_humidity = northern_hemi_df["Humidity"]
north_latitude = northern_hemi_df["Lat"]
plot_linear_regression(north_latitude, north_humidity, 'Humidity (%)', (50,20))
# Out:
# The r-value is: 0.002153746080883438

# %%
# Southern Hemisphere
south_humidity = southern_hemi_df["Humidity"]
south_latitude = southern_hemi_df["Lat"]
plot_linear_regression(south_latitude, south_humidity, 'Humidity (%)', (-50,20))
# Out:
# The r-value is: 0.03958325633921912

# %% [markdown]
# No Relationship whatsoever that could be defined as meaningful in terms of making assumptions or suggestions

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_cloudiness = northern_hemi_df["Cloudiness"]
plot_linear_regression(north_latitude, north_cloudiness, 'Cloudiness (%)', (50,30))
# Out:
# The r-value is: 0.0013867966623353838

# %%
# Southern Hemisphere
south_cloudiness = southern_hemi_df["Cloudiness"]
plot_linear_regression(south_latitude, south_cloudiness, 'Cloudiness (%)', (-50,30))
# Out:
# The r-value is: 0.02032612148994415

# %% [markdown]
# No meaningful trend could be modelled in terms of making assumption or sugesstions

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_windspeed = northern_hemi_df['Wind Speed']
plot_linear_regression(north_latitude, northern_windspeed, 'Wind Speed (%)', (0, 25))
# Out:
# The r-value is: 0.020532433402912283

# %%
# Southern Hemisphere
southern_windspeed = southern_hemi_df['Wind Speed']
plot_linear_regression(south_latitude, southern_windspeed, 'Wind Speed (%)', (50, 20))
# Out:
# The r-value is: 0.007853248255041452

# %% [markdown]
# **Discussion about the linear relationship:** Whilst looking at linear relationships depicted in the graphs above, we are mainly assessing the effects of Latitude on Temperature levels, Wind speed, Humidity or Cloudiness. It is notable to highlight that, the strongest relationship observed in the above mention regressions, was between Temperature and Latitude. In Northern Hemisphere, the relationship was more weaker compared to one in the Southern, however it is also interesting that relationship between Temperature levels and Latitude in Northern and Southern Hemispheres, were exactly the same. Meaning we have relationship in Northern hemisphere, where, if Latitude is increased Temperature seems to decerase as well, in a weakly to moderately correlated manner. However, when increasing Latitude in Southern Hemisphere, Temperature levels tend to decreas as well, but showing stronger correlation between the two factors. There could be no meaningful relationship determined between the Humidity levels and Latitude, as well as in terms of cloudiness. The relationship between Wind speed and Latitude, could be defined as somewhat more formulated. However, Lower Latitude in southern Hemisphere means smaller Wind speeds, whereas the best fit line for Northern hemisphere indicates one might see less wind speed as Latitude increases. Nevertheless, it is also important to note that these relationships are also very weak or maybe even non existent, in the sense of making assumptions or pedictions.s
